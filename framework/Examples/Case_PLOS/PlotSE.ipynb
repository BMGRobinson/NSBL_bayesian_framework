# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy.stats as st
import parse

t_true = np.arange(0,273,0.1)
t_data = np.loadtxt('timedata.dat')
x_data = np.loadtxt('data.dat')
x_true = np.loadtxt('true.dat')

s_true = x_true[0,:]
i_true = x_true[1,:]
r_true = x_true[2,:]
b_true = x_true[3,:]
t_true = x_true[4,:]

import parse

# %%
f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t_true,i_true,linewidth=2,c='tab:blue')
plt.scatter(t_data,x_data,color='w',edgecolors='k',zorder=1,alpha=0.6,label='Data')
plt.axvline(500,color='k', linestyle='--',linewidth=2)
plt.grid(True)
plt.xlim([0,720])
plt.ylim([0,0.06])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Data', fontsize=12)
plt.savefig('figures/data.pdf')
# plt.close()

# %%
## FULL SIRS
t_low,t_up = 0,500


[t,x_mean,x_var] =  parse.parseXML('ModelSIRS_Full-state-estimation0.xml')

xtrue = np.loadtxt('true.dat')

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x_mean[0,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x_mean[0,:]+1.96*np.sqrt(x_var[0,:]),x_mean[0,:]-1.96*np.sqrt(x_var[0,:]),facecolor='tab:blue',alpha=0.5)
plt.plot(t_true,s_true,linewidth=2,c='tab:red',linestyle='--')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
# plt.plot(t_data,x_data,'o',alpha=0.5,c='tab:red')
plt.grid(True)
plt.xlim([t_low,t_up])
# plt.ylim([-15,15])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Susceptible compartment, $S(t)$', fontsize=12)
# plt.savefig('figures/mFull_b.pdf')
# plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x_mean[1,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x_mean[1,:]+1.96*np.sqrt(x_var[5,:]),x_mean[1,:]-1.96*np.sqrt(x_var[5,:]),facecolor='tab:blue',alpha=0.5)
plt.scatter(t_data,x_data,color='w',edgecolors='k',zorder=1,alpha=0.6,label='Data')
plt.plot(t_true,i_true,linewidth=2,c='tab:red',linestyle='--')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
# plt.plot(t_data,4*x_data,'o',alpha=0.2,c='tab:red')
plt.grid(True)
plt.xlim([t_low,t_up])
plt.ylim([0,0.06])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Infectious compartment, $I(t)$', fontsize=12)
# plt.savefig('figures/mFull_i.pdf')
# plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x_mean[2,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x_mean[2,:]+1.96*np.sqrt(x_var[10,:]),x_mean[2,:]-1.96*np.sqrt(x_var[10,:]),facecolor='tab:blue',alpha=0.5)
plt.plot(t_true,r_true,linewidth=2,c='tab:red',linestyle='--')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
plt.grid(True)
plt.xlim([t_low,t_up])
# plt.ylim([-15,15])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Recovered compartment, $R(t)$', fontsize=12)
# plt.savefig('figures/mFull_r.pdf')
# plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x_mean[3,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x_mean[3,:]+1.96*np.sqrt(x_var[15,:]),x_mean[3,:]-1.96*np.sqrt(x_var[15,:]),facecolor='tab:blue',alpha=0.5)
plt.plot(t_true,b_true,linewidth=2,c='tab:red',linestyle='--')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
plt.grid(True)
plt.xlim([t_low,t_up])
# plt.ylim([-15,15])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Infection rate parameter, $\beta(t)$', fontsize=12)
# plt.savefig('figures/mFull_b.pdf')
# plt.close()
# Out:
# Text(0, 0.5, 'Infection rate parameter, $\\beta(t)$')

# %%
f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,(-3.09789127e+01*x_mean[1,:]),linewidth=2)
plt.plot(t,(1.24735379e+01*x_mean[2,:]),linewidth=2)
plt.plot(t,-x_mean[3,:]*x_mean[0,:]*x_mean[1,:],linewidth=2)

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,-(3.12135224e+01*x_mean[1,:]),linewidth=2)
plt.plot(t,-(-3.09789127e+01*x_mean[1,:]),linewidth=2)
plt.plot(t,x_mean[3,:]*x_mean[0,:]*x_mean[1,:],linewidth=2)

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,(3.12135224e+01*x_mean[1,:]),linewidth=2)
plt.plot(t,-(1.24735379e+01*x_mean[2,:]),linewidth=2)

# %%
x = np.linspace(-2,2,100)
plt.plot(x,(np.exp(x)-np.exp(-x))/(np.exp(x)+np.exp(-x)))
# plt.plot(x,(np.exp(x)-1))
plt.plot(x,np.log(1+(np.exp(x)))-np.log(2))
plt.plot(x,x,'--')
plt.grid()

# %%
maps = np.loadtxt('chains/ModelSIRS_Full-map.dat')
re_mu = np.zeros(len(x_mean[0,:]))
re_sigma = np.zeros(len(x_mean[0,:]))

for ii in range(len(x_mean[0,:])):
  Mu = [x_mean[0,ii],x_mean[3,ii]]
  Sigma = [[x_var[0,ii],x_var[3,ii]],[x_var[12,ii],x_var[15,ii]]]

  s_beta = np.random.multivariate_normal(Mu,Sigma,1000)

  re_mu[ii] = np.mean(s_beta[:,0]*s_beta[:,1]/maps[0])
  re_sigma[ii] = np.var(s_beta[:,0]*s_beta[:,1]/maps[0])

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,re_mu,linewidth=2,c='tab:blue')
plt.fill_between(t,re_mu+1.96*np.sqrt(re_sigma),re_mu-1.96*np.sqrt(re_sigma),facecolor='tab:blue',alpha=0.5)
# plt.fill_between(t,re_mu+1.96*np.sqrt(re_sigma),re_mu-1.96*np.sqrt(re_sigma),facecolor='tab:blue',alpha=0.5)
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
for ii in range(len(re_mu)-1):
  if (re_mu[ii+1]-1)/(re_mu[ii]-1) < 0:
    plt.plot([t[ii],t[ii]],[0,3])
plt.grid(True)
plt.xlim([0,364])
plt.ylim([0,3])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Effective reproduction number, $R_e(t)$', fontsize=12)
# plt.savefig('figures/m4_re.pdf')
# plt.close()
# Out:
# Text(0, 0.5, 'Effective reproduction number, $R_e(t)$')

# %%
## SIRS

[t,x1_mean,x1_var] =  parse.parseXML('ModelSIRS_SIRS-state-estimation0.xml')

xtrue = np.loadtxt('true.dat')

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x1_mean[0,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x1_mean[0,:]+1.96*np.sqrt(x1_var[0,:]),x1_mean[0,:]-1.96*np.sqrt(x1_var[0,:]),facecolor='tab:blue',alpha=0.5)
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
# plt.plot(t_data,x_data,'o',alpha=0.5,c='tab:red')
plt.grid(True)
plt.xlim([0,500])
# plt.ylim([-15,15])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Susceptible compartment, $S(t)$', fontsize=12)
# plt.savefig('figures/mSIRS_b.pdf')
# plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x1_mean[1,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x1_mean[1,:]+1.96*np.sqrt(x1_var[5,:]),x1_mean[1,:]-1.96*np.sqrt(x1_var[5,:]),facecolor='tab:blue',alpha=0.5)
plt.scatter(t_data,x_data,color='w',edgecolors='k',zorder=1,alpha=0.6,label='Data')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
# plt.plot(t_data,4*x_data,'o',alpha=0.2,c='tab:red')
plt.grid(True)
plt.xlim([0,500])
plt.ylim([0,0.06])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Infectious compartment, $I(t)$', fontsize=12)
# plt.savefig('figures/mSIRS_i.pdf')
# plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x1_mean[2,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x1_mean[2,:]+1.96*np.sqrt(x1_var[10,:]),x1_mean[2,:]-1.96*np.sqrt(x1_var[10,:]),facecolor='tab:blue',alpha=0.5)
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
plt.grid(True)
plt.xlim([0,500])
# plt.ylim([-15,15])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Recovered compartment, $R(t)$', fontsize=12)
# plt.savefig('figures/mSIRS_r.pdf')
# plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x1_mean[3,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x1_mean[3,:]+1.96*np.sqrt(x1_var[15,:]),x1_mean[3,:]-1.96*np.sqrt(x1_var[15,:]),facecolor='tab:blue',alpha=0.5)
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
plt.grid(True)
plt.xlim([0,500])
# plt.ylim([-15,15])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Infection rate parameter, $\beta(t)$', fontsize=12)
# plt.savefig('figures/mSIRS_b.pdf')
# plt.close()
# Out:
# Text(0, 0.5, 'Infection rate parameter, $\\beta(t)$')

# %%
maps = np.loadtxt('chains/ModelSIRS_SIRS-map.dat')
re1_mu = np.zeros(len(x1_mean[0,:]))
re1_sigma = np.zeros(len(x1_mean[0,:]))

for ii in range(len(x1_mean[0,:])):
  Mu = [x1_mean[0,ii],x1_mean[3,ii]]
  Sigma = [[x1_var[0,ii],x1_var[3,ii]],[x1_var[12,ii],x1_var[15,ii]]]

  s_beta = np.random.multivariate_normal(Mu,Sigma,1000)

  re1_mu[ii] = np.mean(s_beta[:,0]*s_beta[:,1]/maps[0])
  re1_sigma[ii] = np.var(s_beta[:,0]*s_beta[:,1]/maps[0])

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,re1_mu,linewidth=2,c='tab:blue')
plt.fill_between(t,re1_mu+1.96*np.sqrt(re1_sigma),re1_mu-1.96*np.sqrt(re1_sigma),facecolor='tab:blue',alpha=0.5)
# plt.fill_between(t,re_mu+1.96*np.sqrt(re_sigma),re_mu-1.96*np.sqrt(re_sigma),facecolor='tab:blue',alpha=0.5)
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
for ii in range(len(re1_mu)-1):
  if (re1_mu[ii+1]-1)/(re1_mu[ii]-1) < 0:
    plt.plot([t[ii],t[ii]],[0,3])
plt.grid(True)
plt.xlim([0,364])
plt.ylim([0,3])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Effective reproduction number, $R_e(t)$', fontsize=12)
# plt.savefig('figures/m4_re.pdf')
# plt.close()
# Out:
# Text(0, 0.5, 'Effective reproduction number, $R_e(t)$')

# %%
## SIR

[t,x2_mean,x2_var] =  parse.parseXML('ModelSIRS_SIR-state-estimation0.xml')

xtrue = np.loadtxt('true.dat')

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x2_mean[0,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x2_mean[0,:]+1.96*np.sqrt(x2_var[0,:]),x2_mean[0,:]-1.96*np.sqrt(x2_var[0,:]),facecolor='tab:blue',alpha=0.5)
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
# plt.plot(t_data,x_data,'o',alpha=0.5,c='tab:red')
plt.grid(True)
plt.xlim([0,500])
# plt.ylim([-15,15])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Susceptible compartment, $S(t)$', fontsize=12)
# plt.savefig('figures/mSIR_b.pdf')
# plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x2_mean[1,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x2_mean[1,:]+1.96*np.sqrt(x2_var[5,:]),x2_mean[1,:]-1.96*np.sqrt(x2_var[5,:]),facecolor='tab:blue',alpha=0.5)
plt.scatter(t_data,x_data,color='w',edgecolors='k',zorder=1,alpha=0.6,label='Data')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
# plt.plot(t_data,4*x_data,'o',alpha=0.2,c='tab:red')
plt.grid(True)
plt.xlim([0,500])
plt.ylim([0,0.06])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Infectious compartment, $I(t)$', fontsize=12)
# plt.savefig('figures/mSIR_i.pdf')
# plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x2_mean[2,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x2_mean[2,:]+1.96*np.sqrt(x2_var[10,:]),x2_mean[2,:]-1.96*np.sqrt(x2_var[10,:]),facecolor='tab:blue',alpha=0.5)
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
plt.grid(True)
plt.xlim([0,500])
# plt.ylim([-15,15])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Recovered compartment, $R(t)$', fontsize=12)
# plt.savefig('figures/mSIR_r.pdf')
# plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x2_mean[3,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x2_mean[3,:]+1.96*np.sqrt(x2_var[15,:]),x2_mean[3,:]-1.96*np.sqrt(x2_var[15,:]),facecolor='tab:blue',alpha=0.5)
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
plt.grid(True)
plt.xlim([0,500])
# plt.ylim([-15,15])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Infection rate parameter, $\beta(t)$', fontsize=12)
# plt.savefig('figures/mSIR_b.pdf')
# plt.close()
# Out:
# Text(0, 0.5, 'Infection rate parameter, $\\beta(t)$')

# %%
maps = np.loadtxt('chains/ModelSIRS_SIR-map.dat')
re2_mu = np.zeros(len(x2_mean[0,:]))
re2_sigma = np.zeros(len(x2_mean[0,:]))

for ii in range(len(x2_mean[0,:])):
  Mu = [x2_mean[0,ii],x2_mean[3,ii]]
  Sigma = [[x2_var[0,ii],x2_var[3,ii]],[x2_var[12,ii],x2_var[15,ii]]]

  s_beta = np.random.multivariate_normal(Mu,Sigma,1000)

  re2_mu[ii] = np.mean(s_beta[:,0]*s_beta[:,1]/maps[0])
  re2_sigma[ii] = np.var(s_beta[:,0]*s_beta[:,1]/maps[0])

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,re2_mu,linewidth=2,c='tab:blue')
plt.fill_between(t,re2_mu+1.96*np.sqrt(re2_sigma),re2_mu-1.96*np.sqrt(re2_sigma),facecolor='tab:blue',alpha=0.5)
# plt.fill_between(t,re_mu+1.96*np.sqrt(re_sigma),re_mu-1.96*np.sqrt(re_sigma),facecolor='tab:blue',alpha=0.5)
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
for ii in range(len(re2_mu)-1):
  if (re2_mu[ii+1]-1)/(re2_mu[ii]-1) < 0:
    plt.plot([t[ii],t[ii]],[0,3])
plt.grid(True)
plt.xlim([0,364])
plt.ylim([0,3])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Effective reproduction number, $R_e(t)$', fontsize=12)
# plt.savefig('figures/m4_re.pdf')
# plt.close()
# Out:
# Text(0, 0.5, 'Effective reproduction number, $R_e(t)$')

# %%
## SIS

[t,x3_mean,x3_var] =  parse.parseXML('ModelSIRS_SIS-state-estimation0.xml')

xtrue = np.loadtxt('true.dat')

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x3_mean[0,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x3_mean[0,:]+1.96*np.sqrt(x3_var[0,:]),x3_mean[0,:]-1.96*np.sqrt(x3_var[0,:]),facecolor='tab:blue',alpha=0.5)
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
# plt.plot(t_data,x_data,'o',alpha=0.5,c='tab:red')
plt.grid(True)
plt.xlim([0,500])
# plt.ylim([-15,15])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Susceptible compartment, $S(t)$', fontsize=12)
# plt.savefig('figures/mSIS_b.pdf')
# plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x3_mean[1,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x3_mean[1,:]+1.96*np.sqrt(x3_var[4,:]),x3_mean[1,:]-1.96*np.sqrt(x3_var[4,:]),facecolor='tab:blue',alpha=0.5)
plt.scatter(t_data,x_data,color='w',edgecolors='k',zorder=1,alpha=0.6,label='Data')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
# plt.plot(t_data,4*x_data,'o',alpha=0.2,c='tab:red')
plt.grid(True)
plt.xlim([0,500])
plt.ylim([0,0.06])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Infectious compartment, $I(t)$', fontsize=12)
# plt.savefig('figures/mSIS_i.pdf')
# plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x3_mean[2,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x3_mean[2,:]+1.96*np.sqrt(x3_var[8,:]),x3_mean[2,:]-1.96*np.sqrt(x3_var[8,:]),facecolor='tab:blue',alpha=0.5)
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
plt.grid(True)
plt.xlim([0,500])
# plt.ylim([-15,15])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Infection rate parameter, $\beta(t)$', fontsize=12)
# plt.savefig('figures/mSIS_b.pdf')
# plt.close()
# Out:
# Text(0, 0.5, 'Infection rate parameter, $\\beta(t)$')

# %%
maps = np.loadtxt('chains/ModelSIRS_SIS-map.dat')
re3_mu = np.zeros(len(x3_mean[0,:]))
re3_sigma = np.zeros(len(x3_mean[0,:]))

for ii in range(len(x3_mean[0,:])):
  Mu = [x3_mean[0,ii],x3_mean[2,ii]]
  Sigma = [[x3_var[0,ii],x3_var[2,ii]],[x3_var[6,ii],x3_var[8,ii]]]

  s_beta = np.random.multivariate_normal(Mu,Sigma,1000)

  re3_mu[ii] = np.mean(s_beta[:,0]*s_beta[:,1]/maps[0])
  re3_sigma[ii] = np.var(s_beta[:,0]*s_beta[:,1]/maps[0])

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,re3_mu,linewidth=2,c='tab:blue')
plt.fill_between(t,re3_mu+1.96*np.sqrt(re3_sigma),re3_mu-1.96*np.sqrt(re3_sigma),facecolor='tab:blue',alpha=0.5)
# plt.fill_between(t,re_mu+1.96*np.sqrt(re_sigma),re_mu-1.96*np.sqrt(re_sigma),facecolor='tab:blue',alpha=0.5)
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
for ii in range(len(re_mu)-1):
  if (re3_mu[ii+1]-1)/(re3_mu[ii]-1) < 0:
    plt.plot([t[ii],t[ii]],[0,3])
plt.grid(True)
plt.xlim([0,364])
plt.ylim([0,3])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Effective reproduction number, $R_e(t)$', fontsize=12)
# plt.savefig('figures/m4_re.pdf')
# plt.close()
# Out:
# Text(0, 0.5, 'Effective reproduction number, $R_e(t)$')

# %%
## Compare all

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t_true,s_true,linewidth=2,c='tab:red',linestyle='--')
plt.plot(t,x_mean[0,:],linewidth=2,c='tab:blue')
plt.plot(t,x1_mean[0,:],linewidth=2,c='tab:orange')
plt.plot(t,x2_mean[0,:],linewidth=2,c='tab:green')
plt.plot(t,x3_mean[0,:],linewidth=2,c='tab:purple')
plt.fill_between(t,x_mean[0,:]+1.96*np.sqrt(x_var[0,:]),x_mean[0,:]-1.96*np.sqrt(x_var[0,:]),facecolor='tab:blue',alpha=0.5)
plt.fill_between(t,x1_mean[0,:]+1.96*np.sqrt(x1_var[0,:]),x1_mean[0,:]-1.96*np.sqrt(x1_var[0,:]),facecolor='tab:orange',alpha=0.5)
plt.fill_between(t,x2_mean[0,:]+1.96*np.sqrt(x2_var[0,:]),x2_mean[0,:]-1.96*np.sqrt(x2_var[0,:]),facecolor='tab:green',alpha=0.5)
plt.fill_between(t,x3_mean[0,:]+1.96*np.sqrt(x3_var[0,:]),x3_mean[0,:]-1.96*np.sqrt(x3_var[0,:]),facecolor='tab:purple',alpha=0.5)
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
# plt.plot(t_data,x_data,'o',alpha=0.5,c='tab:red')
plt.grid(True)
plt.xlim([0,500])
# plt.ylim([-15,15])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Susceptible compartment, $S(t)$', fontsize=12)
# plt.savefig('figures/mSIRS_b.pdf')
# plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t_true,i_true,linewidth=2,c='tab:red',linestyle='--')
plt.plot(t,x_mean[1,:],linewidth=2,c='tab:blue')
plt.plot(t,x1_mean[1,:],linewidth=2,c='tab:orange')
plt.plot(t,x2_mean[1,:],linewidth=2,c='tab:green')
plt.plot(t,x3_mean[1,:],linewidth=2,c='tab:purple')
plt.fill_between(t,x_mean[1,:]+1.96*np.sqrt(x_var[5,:]),x_mean[1,:]-1.96*np.sqrt(x_var[5,:]),facecolor='tab:blue',alpha=0.5)
plt.fill_between(t,x1_mean[1,:]+1.96*np.sqrt(x1_var[5,:]),x1_mean[1,:]-1.96*np.sqrt(x1_var[5,:]),facecolor='tab:orange',alpha=0.5)
plt.fill_between(t,x2_mean[1,:]+1.96*np.sqrt(x2_var[5,:]),x2_mean[1,:]-1.96*np.sqrt(x2_var[5,:]),facecolor='tab:green',alpha=0.5)
plt.fill_between(t,x3_mean[1,:]+1.96*np.sqrt(x3_var[4,:]),x3_mean[1,:]-1.96*np.sqrt(x3_var[4,:]),facecolor='tab:purple',alpha=0.5)
plt.scatter(t_data,x_data,color='w',edgecolors='k',zorder=1,alpha=0.6,label='Data')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
# plt.plot(t_data,4*x_data,'o',alpha=0.2,c='tab:red')
plt.grid(True)
plt.xlim([0,500])
plt.ylim([0,0.06])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Infectious compartment, $I(t)$', fontsize=12)
# plt.savefig('figures/mSIRS_i.pdf')
# plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t_true,r_true,linewidth=2,c='tab:red',linestyle='--')
plt.plot(t,x_mean[2,:],linewidth=2,c='tab:blue')
plt.plot(t,x1_mean[2,:],linewidth=2,c='tab:orange')
plt.plot(t,x2_mean[2,:],linewidth=2,c='tab:green')
plt.fill_between(t,x_mean[2,:]+1.96*np.sqrt(x_var[10,:]),x_mean[2,:]-1.96*np.sqrt(x_var[10,:]),facecolor='tab:blue',alpha=0.5)
plt.fill_between(t,x1_mean[2,:]+1.96*np.sqrt(x1_var[10,:]),x1_mean[2,:]-1.96*np.sqrt(x1_var[10,:]),facecolor='tab:orange',alpha=0.5)
plt.fill_between(t,x2_mean[2,:]+1.96*np.sqrt(x2_var[10,:]),x2_mean[2,:]-1.96*np.sqrt(x2_var[10,:]),facecolor='tab:green',alpha=0.5)
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
plt.grid(True)
plt.xlim([0,500])
# plt.ylim([-15,15])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Recovered compartment, $R(t)$', fontsize=12)
# plt.savefig('figures/mSIRS_r.pdf')
# plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t_true,b_true,linewidth=2,c='tab:red',linestyle='--')
plt.plot(t,x_mean[3,:],linewidth=2,c='tab:blue')
plt.plot(t,x1_mean[3,:],linewidth=2,c='tab:orange')
plt.plot(t,x2_mean[3,:],linewidth=2,c='tab:green')
plt.plot(t,x3_mean[2,:],linewidth=2,c='tab:purple')
plt.fill_between(t,x_mean[3,:]+1.96*np.sqrt(x_var[15,:]),x_mean[3,:]-1.96*np.sqrt(x_var[15,:]),facecolor='tab:blue',alpha=0.5)
plt.fill_between(t,x1_mean[3,:]+1.96*np.sqrt(x1_var[15,:]),x1_mean[3,:]-1.96*np.sqrt(x1_var[15,:]),facecolor='tab:orange',alpha=0.5)
plt.fill_between(t,x2_mean[3,:]+1.96*np.sqrt(x2_var[15,:]),x2_mean[3,:]-1.96*np.sqrt(x2_var[15,:]),facecolor='tab:green',alpha=0.5)
plt.fill_between(t,x3_mean[2,:]+1.96*np.sqrt(x3_var[8,:]),x3_mean[2,:]-1.96*np.sqrt(x3_var[8,:]),facecolor='tab:purple',alpha=0.5)
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
plt.grid(True)
plt.xlim([0,500])
# plt.ylim([-15,15])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Infection rate parameter, $\beta(t)$', fontsize=12)
# plt.savefig('figures/mSIRS_b.pdf')
# plt.close()
# Out:
# Text(0, 0.5, 'Infection rate parameter, $\\beta(t)$')

# %%
## Compare all

f, ax = plt.subplots(1, figsize=(15,3))
# plt.plot(t,x_mean[0,:],linewidth=2,c='tab:blue')
plt.plot(t,x2_mean[0,:],linewidth=2,c='tab:blue',label='SIR model')
plt.plot(t,x3_mean[0,:],linewidth=2,c='tab:orange',label='SIS model')
plt.plot(t,x1_mean[0,:],linewidth=2,c='tab:green',label='SIRS model')
plt.plot(t_true,s_true,linewidth=2,c='tab:red',linestyle='--',label='Truth')
# plt.fill_between(t,x_mean[0,:]+1.96*np.sqrt(x_var[0,:]),x_mean[0,:]-1.96*np.sqrt(x_var[0,:]),facecolor='tab:blue',alpha=0.5)
plt.fill_between(t,x2_mean[0,:]+1.96*np.sqrt(x2_var[0,:]),x2_mean[0,:]-1.96*np.sqrt(x2_var[0,:]),facecolor='tab:blue',alpha=0.5)
plt.fill_between(t,x3_mean[0,:]+1.96*np.sqrt(x3_var[0,:]),x3_mean[0,:]-1.96*np.sqrt(x3_var[0,:]),facecolor='tab:orange',alpha=0.5)
plt.fill_between(t,x1_mean[0,:]+1.96*np.sqrt(x1_var[0,:]),x1_mean[0,:]-1.96*np.sqrt(x1_var[0,:]),facecolor='tab:green',alpha=0.5)
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
# plt.plot(t_data,x_data,'o',alpha=0.5,c='tab:red')
plt.grid(True)
plt.xlim([0,500])
plt.ylim(top=1)
plt.legend(loc='lower left', fontsize=14)
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Susceptible compartment, $S(t)$', fontsize=12)
plt.savefig('figures/summary_s.pdf')
# plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
# plt.plot(t,x_mean[1,:],linewidth=2,c='tab:blue')
plt.plot(t,x2_mean[1,:],linewidth=2,c='tab:blue')
plt.plot(t,x3_mean[1,:],linewidth=2,c='tab:orange')
plt.plot(t,x1_mean[1,:],linewidth=2,c='tab:green')
plt.plot(t_true,i_true,linewidth=2,c='tab:red',linestyle='--')
# plt.fill_between(t,x_mean[1,:]+1.96*np.sqrt(x_var[5,:]),x_mean[1,:]-1.96*np.sqrt(x_var[5,:]),facecolor='tab:blue',alpha=0.5)
plt.fill_between(t,x2_mean[1,:]+1.96*np.sqrt(x2_var[5,:]),x2_mean[1,:]-1.96*np.sqrt(x2_var[5,:]),facecolor='tab:blue',alpha=0.5)
plt.fill_between(t,x3_mean[1,:]+1.96*np.sqrt(x3_var[4,:]),x3_mean[1,:]-1.96*np.sqrt(x3_var[4,:]),facecolor='tab:orange',alpha=0.5)
plt.fill_between(t,x1_mean[1,:]+1.96*np.sqrt(x1_var[5,:]),x1_mean[1,:]-1.96*np.sqrt(x1_var[5,:]),facecolor='tab:green',alpha=0.5)
plt.scatter(t_data,x_data,color='w',edgecolors='k',zorder=1,alpha=0.6,label='Data')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
# plt.plot(t_data,4*x_data,'o',alpha=0.2,c='tab:red')
plt.grid(True)
plt.xlim([0,500])
plt.ylim(bottom=0)
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Infectious compartment, $I(t)$', fontsize=12)
plt.savefig('figures/summary_i.pdf')
# plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
# plt.plot(t,x_mean[2,:],linewidth=2,c='tab:blue')
plt.plot(t,x2_mean[2,:],linewidth=2,c='tab:blue')
plt.plot(t,x1_mean[2,:],linewidth=2,c='tab:green')
plt.plot(t,np.zeros(len(t)),linewidth=2,c='tab:orange')
plt.plot(t_true,r_true,linewidth=2,c='tab:red',linestyle='--')
# plt.fill_between(t,x_mean[2,:]+1.96*np.sqrt(x_var[10,:]),x_mean[2,:]-1.96*np.sqrt(x_var[10,:]),facecolor='tab:blue',alpha=0.5)
plt.fill_between(t,x2_mean[2,:]+1.96*np.sqrt(x2_var[10,:]),x2_mean[2,:]-1.96*np.sqrt(x2_var[10,:]),facecolor='tab:blue',alpha=0.5)
plt.fill_between(t,x1_mean[2,:]+1.96*np.sqrt(x1_var[10,:]),x1_mean[2,:]-1.96*np.sqrt(x1_var[10,:]),facecolor='tab:green',alpha=0.5)
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
plt.grid(True)
plt.xlim([0,500])
plt.ylim(bottom=0)
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Recovered compartment, $R(t)$', fontsize=12)
plt.savefig('figures/summary_r.pdf')
# plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
# plt.plot(t,x_mean[3,:],linewidth=2,c='tab:blue')
plt.plot(t,x2_mean[3,:],linewidth=2,c='tab:blue')
plt.plot(t,x3_mean[2,:],linewidth=2,c='tab:orange')
plt.plot(t,x1_mean[3,:],linewidth=2,c='tab:green')
plt.plot(t_true,b_true,linewidth=2,c='tab:red',linestyle='--')
# plt.fill_between(t,x_mean[3,:]+1.96*np.sqrt(x_var[15,:]),x_mean[3,:]-1.96*np.sqrt(x_var[15,:]),facecolor='tab:blue',alpha=0.5)
plt.fill_between(t,x2_mean[3,:]+1.96*np.sqrt(x2_var[15,:]),x2_mean[3,:]-1.96*np.sqrt(x2_var[15,:]),facecolor='tab:blue',alpha=0.5)
plt.fill_between(t,x3_mean[2,:]+1.96*np.sqrt(x3_var[8,:]),x3_mean[2,:]-1.96*np.sqrt(x3_var[8,:]),facecolor='tab:orange',alpha=0.5)
plt.fill_between(t,x1_mean[3,:]+1.96*np.sqrt(x1_var[15,:]),x1_mean[3,:]-1.96*np.sqrt(x1_var[15,:]),facecolor='tab:green',alpha=0.5)
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
plt.grid(True)
plt.xlim([0,500])
# plt.ylim([-15,15])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Infection rate parameter, $\beta(t)$', fontsize=12)
plt.savefig('figures/summary_b.pdf')
# plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,re2_mu,linewidth=2,c='tab:blue')
plt.fill_between(t,re2_mu+1.96*np.sqrt(re2_sigma),re2_mu-1.96*np.sqrt(re2_sigma),facecolor='tab:blue',alpha=0.5)
plt.plot(t,re3_mu,linewidth=2,c='tab:orange')
plt.fill_between(t,re3_mu+1.96*np.sqrt(re3_sigma),re3_mu-1.96*np.sqrt(re3_sigma),facecolor='tab:orange',alpha=0.5)
plt.plot(t,re1_mu,linewidth=2,c='tab:green')
plt.fill_between(t,re1_mu+1.96*np.sqrt(re1_sigma),re1_mu-1.96*np.sqrt(re1_sigma),facecolor='tab:green',alpha=0.5)
plt.grid(True)
plt.xlim([0,364])
plt.ylim([0,3])
plt.xlabel('Time (days)', fontsize=12)
plt.ylabel(r'Effective reproduction number, $R_e(t)$', fontsize=12)
# plt.savefig('figures/m4_re.pdf')
# plt.close()
# Out:
# Text(0, 0.5, 'Effective reproduction number, $R_e(t)$')
